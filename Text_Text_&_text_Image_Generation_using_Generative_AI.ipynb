# %%
# !nvidia-smi
# Out:
# Thu Sep 26 10:34:55 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyB2Bm_-I1lGiwjX9VHUVEl3DdSdGpGkSVA'

# %%
# !pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 19.2 MB/s eta 0:00:00

# %%
import google.generativeai as genai

genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-1.5-pro')

# %%
response = model.generate_content("what is today?")
print (response.text)
# Out:
# I do not have access to real-time information, including the current date. To get today's date, I recommend checking a calendar or a digital device with date and time settings.

# %%
model1 = genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content("what is today?")
print (response.text)
# Out:
# I do not have access to real-time information, including the current date. To get today's date, I recommend checking a calendar or asking a device with internet access.

# %%
model2 = genai.GenerativeModel('models/gemini-1.5-flash-8b-exp-0924')

# %%
response = model.generate_content("what is today?")
print (response.text)
# Out:
# I do not have access to real-time information, including the current date. To get today's date, I recommend checking a calendar or asking a device with internet access.

# %%
response2 = model2.generate_content("what is life span of person")
print(response2.text)
# Out:
# The lifespan of a person is highly variable, and depends on many factors.  There's no single answer.  While the *average* lifespan has increased significantly over the centuries,  the *maximum* lifespan is still a subject of ongoing research and debate.

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-1.5-flash-002

# %%
# %%time
response3 = model2.generate_content("what is the meaning of dream & goal? how to reach the dream")
# Out:
# CPU times: user 75.3 ms, sys: 6.01 ms, total: 81.3 ms
# Wall time: 5.89 s

# %%
to_markdown(response3.text)
# Out:
# > A **dream** is a vision of something desired or aspired to, often something significant and potentially life-changing.  It's a powerful, emotional ideal that motivates and inspires.  Dreams can be about personal fulfillment, career aspirations, relationships, experiences, or even societal impact.  They're often large-scale and long-term.  They can be vague or specific, but always hold an element of hope and yearning.
# >
# > A **goal** is a concrete, measurable, achievable, relevant, and time-bound (SMART) objective that helps you move towards your dream. Goals break down the larger dream into smaller, manageable steps.  They provide a clear path and a way to track progress.  Goals are action-oriented and focused on specific outcomes.
# >
# > **How to Reach Your Dream:**
# >
# > Reaching a dream isn't a simple, linear process.  It requires consistent effort, adaptation, and a willingness to learn and grow. Here's a breakdown of steps:
# >
# > 1. **Define Your Dream:**
# ...

# %%
#!curl -o image.jpg https://t0.gstatic.com/licensed-image?q=tbn:ANd9GcQ_Kevbk21QBRy-PgB4kQpS79brbmmEG7m3VOTShAn4PecDU5H5UxrJxE3Dw1JiaG17V88QIol19-3TM2wCHw

# %%
import PIL.Image
img = PIL.Image.open('/content/download (1).jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=194x183>

# %%
model4 = genai.GenerativeModel('models/gemini-1.5-flash-8b-exp-0924')

# %%
response4 = model4.generate_content(img)

to_markdown(response4.text)
# Out:
# > The image depicts a scene of helping another person.  A person is reaching down to assist someone who is seated or fallen.  It evokes themes of:
# >
# > * **Compassion and empathy:** The image highlights the act of caring for and supporting someone in need.
# > * **Helping others:**  The action of extending a hand symbolizes offering support and assistance.
# > * **Human connection and solidarity:**  The interaction between the two people underscores the bonds of humanity.
# > * **Overcoming adversity:**  The person being helped could be facing a challenge, and the assistance signifies a means of overcoming that difficulty.
# > * **Hope and resilience:** The image carries a sense of optimism, suggesting that with help, challenges can be overcome.
# >
# > The setting, with the sunset/sunrise sky, adds a layer of symbolism and emotion, making the image even more evocative.

# %%
import PIL.Image
img = PIL.Image.open('/content/download.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=209x148>

# %%
response4 = model4.generate_content(img)

to_markdown(response4.text)
# Out:
# > The image shows a group of diverse young adults, all smiling and laughing.  They appear to be close friends, enjoying each other's company.  The group is a mix of ethnicities and genders, suggesting a sense of community and inclusivity.  The overall feeling is one of happiness and camaraderie.
